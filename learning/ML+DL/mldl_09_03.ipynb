# %% [markdown]
# # LSTM 신경망

# %%
from tensorflow.keras.datasets import imdb
from sklearn.model_selection import train_test_split
(train_input,train_target),(test_input,test_target) = imdb.load_data(num_words=500)
train_input,val_input,train_target,val_target = train_test_split(train_input,train_target,test_size=0.2,random_state=42)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
train_seq = pad_sequences(train_input,maxlen=100)
val_seq = pad_sequences(val_input,maxlen=100)

# %% [markdown]
# LSTM구조 또한 SimpleRNN 클래스와 같다

# %%
from tensorflow import keras
model = keras.Sequential()
model.add(keras.layers.Embedding(500,16,input_length=100))
model.add(keras.layers.LSTM(8))
model.add(keras.layers.Dense(1,activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 100, 16)           8000
#
#  lstm_3 (LSTM)               (None, 8)                 800
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,809
# Trainable params: 8,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model.compile(optimizer=rmsprop, loss='binary_crossentropy', 
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint('./drive/MyDrive/개인 공부/ML_DL/data/best-lstm-model.h5', 
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 21s 56ms/step - loss: 0.6926 - accuracy: 0.5336 - val_loss: 0.6918 - val_accuracy: 0.5600
# Epoch 2/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.6911 - accuracy: 0.5706 - val_loss: 0.6902 - val_accuracy: 0.5908
# Epoch 3/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.6887 - accuracy: 0.6018 - val_loss: 0.6872 - val_accuracy: 0.6118
# Epoch 4/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.6843 - accuracy: 0.6216 - val_loss: 0.6817 - val_accuracy: 0.6288
# Epoch 5/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.6758 - accuracy: 0.6443 - val_loss: 0.6701 - val_accuracy: 0.6552
# Epoch 6/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.6550 - accuracy: 0.6717 - val_loss: 0.6378 - val_accuracy: 0.6744
# Epoch 7/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.5995 - accuracy: 0.7142 - val_loss: 0.5800 - val_accuracy: 0.7256
# Epoch 8/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.5623 - accuracy: 0.7384 - val_loss: 0.5567 - val_accuracy: 0.7398
# Epoch 9/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.5404 - accuracy: 0.7527 - val_loss: 0.5371 - val_accuracy: 0.7480
# Epoch 10/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.5223 - accuracy: 0.7642 - val_loss: 0.5210 - val_accuracy: 0.7598
# Epoch 11/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.5065 - accuracy: 0.7720 - val_loss: 0.5090 - val_accuracy: 0.7700
# Epoch 12/100
# 313/313 [==============================] - 18s 59ms/step - loss: 0.4930 - accuracy: 0.7803 - val_loss: 0.4957 - val_accuracy: 0.7748
# Epoch 13/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.4807 - accuracy: 0.7871 - val_loss: 0.4860 - val_accuracy: 0.7778
# Epoch 14/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4699 - accuracy: 0.7914 - val_loss: 0.4775 - val_accuracy: 0.7788
# Epoch 15/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4611 - accuracy: 0.7954 - val_loss: 0.4708 - val_accuracy: 0.7838
# Epoch 16/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4534 - accuracy: 0.7999 - val_loss: 0.4684 - val_accuracy: 0.7824
# Epoch 17/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4475 - accuracy: 0.8030 - val_loss: 0.4610 - val_accuracy: 0.7874
# Epoch 18/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4421 - accuracy: 0.8049 - val_loss: 0.4570 - val_accuracy: 0.7900
# Epoch 19/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4379 - accuracy: 0.8062 - val_loss: 0.4539 - val_accuracy: 0.7916
# Epoch 20/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.4345 - accuracy: 0.8091 - val_loss: 0.4513 - val_accuracy: 0.7928
# Epoch 21/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4309 - accuracy: 0.8113 - val_loss: 0.4485 - val_accuracy: 0.7962
# Epoch 22/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4284 - accuracy: 0.8116 - val_loss: 0.4542 - val_accuracy: 0.7918
# Epoch 23/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4251 - accuracy: 0.8114 - val_loss: 0.4483 - val_accuracy: 0.7930
# Epoch 24/100
# 313/313 [==============================] - 17s 54ms/step - loss: 0.4234 - accuracy: 0.8131 - val_loss: 0.4523 - val_accuracy: 0.7878
# Epoch 25/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4220 - accuracy: 0.8142 - val_loss: 0.4427 - val_accuracy: 0.7984
# Epoch 26/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4200 - accuracy: 0.8133 - val_loss: 0.4440 - val_accuracy: 0.7966
# Epoch 27/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4191 - accuracy: 0.8138 - val_loss: 0.4444 - val_accuracy: 0.7952
# Epoch 28/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4177 - accuracy: 0.8145 - val_loss: 0.4393 - val_accuracy: 0.7984
# Epoch 29/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4162 - accuracy: 0.8141 - val_loss: 0.4387 - val_accuracy: 0.7998
# Epoch 30/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4152 - accuracy: 0.8144 - val_loss: 0.4384 - val_accuracy: 0.7982
# Epoch 31/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4140 - accuracy: 0.8158 - val_loss: 0.4384 - val_accuracy: 0.7992
# Epoch 32/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4128 - accuracy: 0.8163 - val_loss: 0.4384 - val_accuracy: 0.7966
# Epoch 33/100
# 313/313 [==============================] - 18s 59ms/step - loss: 0.4121 - accuracy: 0.8151 - val_loss: 0.4356 - val_accuracy: 0.8004
# Epoch 34/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4115 - accuracy: 0.8160 - val_loss: 0.4354 - val_accuracy: 0.8024
# Epoch 35/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4104 - accuracy: 0.8156 - val_loss: 0.4360 - val_accuracy: 0.8008
# Epoch 36/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4097 - accuracy: 0.8170 - val_loss: 0.4391 - val_accuracy: 0.7998
# Epoch 37/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4088 - accuracy: 0.8170 - val_loss: 0.4376 - val_accuracy: 0.7936

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %%
test_seq = pad_sequences(test_input,maxlen=100)
# model.evaluate(test_seq,test_target)

# %%
from tensorflow import keras
model2 = keras.Sequential()
model2.add(keras.layers.Embedding(500,16,input_length=100))
# 드롭아웃 적용
model2.add(keras.layers.LSTM(8,dropout=0.3))
model2.add(keras.layers.Dense(1,activation="sigmoid"))
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 16)           8000
#
#  lstm_1 (LSTM)               (None, 8)                 800
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,809
# Trainable params: 8,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model2.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint('./drive/MyDrive/개인 공부/ML_DL/data/best-lstm-dropout-model.h5', 
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)

history = model2.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 22s 56ms/step - loss: 0.6928 - accuracy: 0.5307 - val_loss: 0.6924 - val_accuracy: 0.5480
# Epoch 2/100
# 313/313 [==============================] - 17s 53ms/step - loss: 0.6916 - accuracy: 0.5612 - val_loss: 0.6909 - val_accuracy: 0.5954
# Epoch 3/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.6897 - accuracy: 0.5977 - val_loss: 0.6882 - val_accuracy: 0.6214
# Epoch 4/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.6850 - accuracy: 0.6335 - val_loss: 0.6807 - val_accuracy: 0.6600
# Epoch 5/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.6676 - accuracy: 0.6799 - val_loss: 0.6461 - val_accuracy: 0.6988
# Epoch 6/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.6239 - accuracy: 0.6988 - val_loss: 0.6085 - val_accuracy: 0.7070
# Epoch 7/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.5984 - accuracy: 0.7139 - val_loss: 0.5864 - val_accuracy: 0.7264
# Epoch 8/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.5764 - accuracy: 0.7317 - val_loss: 0.5642 - val_accuracy: 0.7450
# Epoch 9/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.5550 - accuracy: 0.7473 - val_loss: 0.5434 - val_accuracy: 0.7580
# Epoch 10/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.5350 - accuracy: 0.7595 - val_loss: 0.5254 - val_accuracy: 0.7686
# Epoch 11/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.5189 - accuracy: 0.7704 - val_loss: 0.5098 - val_accuracy: 0.7736
# Epoch 12/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.5024 - accuracy: 0.7775 - val_loss: 0.4981 - val_accuracy: 0.7756
# Epoch 13/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.4914 - accuracy: 0.7825 - val_loss: 0.4869 - val_accuracy: 0.7874
# Epoch 14/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.4794 - accuracy: 0.7898 - val_loss: 0.4785 - val_accuracy: 0.7868
# Epoch 15/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.4729 - accuracy: 0.7911 - val_loss: 0.4722 - val_accuracy: 0.7836
# Epoch 16/100
# 313/313 [==============================] - 18s 56ms/step - loss: 0.4645 - accuracy: 0.7932 - val_loss: 0.4665 - val_accuracy: 0.7922
# Epoch 17/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.4597 - accuracy: 0.7982 - val_loss: 0.4627 - val_accuracy: 0.7928
# Epoch 18/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4542 - accuracy: 0.7966 - val_loss: 0.4591 - val_accuracy: 0.7938
# Epoch 19/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4514 - accuracy: 0.7997 - val_loss: 0.4549 - val_accuracy: 0.7952
# Epoch 20/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4463 - accuracy: 0.8005 - val_loss: 0.4531 - val_accuracy: 0.7912
# Epoch 21/100
# 313/313 [==============================] - 18s 59ms/step - loss: 0.4422 - accuracy: 0.8049 - val_loss: 0.4500 - val_accuracy: 0.7960
# Epoch 22/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4394 - accuracy: 0.8034 - val_loss: 0.4486 - val_accuracy: 0.7966
# Epoch 23/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4364 - accuracy: 0.8042 - val_loss: 0.4473 - val_accuracy: 0.7992
# Epoch 24/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4344 - accuracy: 0.8047 - val_loss: 0.4450 - val_accuracy: 0.7920
# Epoch 25/100
# 313/313 [==============================] - 18s 59ms/step - loss: 0.4327 - accuracy: 0.8059 - val_loss: 0.4438 - val_accuracy: 0.7940
# Epoch 26/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4325 - accuracy: 0.8048 - val_loss: 0.4436 - val_accuracy: 0.7994
# Epoch 27/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4308 - accuracy: 0.8063 - val_loss: 0.4404 - val_accuracy: 0.7976
# Epoch 28/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4280 - accuracy: 0.8044 - val_loss: 0.4396 - val_accuracy: 0.8010
# Epoch 29/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.4269 - accuracy: 0.8087 - val_loss: 0.4389 - val_accuracy: 0.8026
# Epoch 30/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4245 - accuracy: 0.8091 - val_loss: 0.4390 - val_accuracy: 0.7944
# Epoch 31/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4237 - accuracy: 0.8077 - val_loss: 0.4371 - val_accuracy: 0.8002
# Epoch 32/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4216 - accuracy: 0.8099 - val_loss: 0.4370 - val_accuracy: 0.8008
# Epoch 33/100
# 313/313 [==============================] - 19s 59ms/step - loss: 0.4221 - accuracy: 0.8087 - val_loss: 0.4360 - val_accuracy: 0.7964
# Epoch 34/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4207 - accuracy: 0.8108 - val_loss: 0.4389 - val_accuracy: 0.8012
# Epoch 35/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4192 - accuracy: 0.8108 - val_loss: 0.4358 - val_accuracy: 0.7964
# Epoch 36/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4208 - accuracy: 0.8068 - val_loss: 0.4342 - val_accuracy: 0.7998
# Epoch 37/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.4207 - accuracy: 0.8077 - val_loss: 0.4340 - val_accuracy: 0.8018
# Epoch 38/100
# 313/313 [==============================] - 17s 55ms/step - loss: 0.4172 - accuracy: 0.8105 - val_loss: 0.4342 - val_accuracy: 0.7972
# Epoch 39/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4180 - accuracy: 0.8105 - val_loss: 0.4339 - val_accuracy: 0.8024
# Epoch 40/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4145 - accuracy: 0.8119 - val_loss: 0.4331 - val_accuracy: 0.8006
# Epoch 41/100
# 313/313 [==============================] - 20s 62ms/step - loss: 0.4160 - accuracy: 0.8094 - val_loss: 0.4329 - val_accuracy: 0.8026
# Epoch 42/100
# 313/313 [==============================] - 18s 59ms/step - loss: 0.4144 - accuracy: 0.8111 - val_loss: 0.4319 - val_accuracy: 0.8008
# Epoch 43/100
# 313/313 [==============================] - 17s 56ms/step - loss: 0.4146 - accuracy: 0.8126 - val_loss: 0.4330 - val_accuracy: 0.7992
# Epoch 44/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4130 - accuracy: 0.8106 - val_loss: 0.4316 - val_accuracy: 0.7992
# Epoch 45/100
# 313/313 [==============================] - 19s 59ms/step - loss: 0.4126 - accuracy: 0.8126 - val_loss: 0.4317 - val_accuracy: 0.8024
# Epoch 46/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4116 - accuracy: 0.8111 - val_loss: 0.4336 - val_accuracy: 0.8014
# Epoch 47/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4121 - accuracy: 0.8099 - val_loss: 0.4311 - val_accuracy: 0.8020
# Epoch 48/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4118 - accuracy: 0.8123 - val_loss: 0.4317 - val_accuracy: 0.8030
# Epoch 49/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.4127 - accuracy: 0.8108 - val_loss: 0.4305 - val_accuracy: 0.8010
# Epoch 50/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4109 - accuracy: 0.8123 - val_loss: 0.4309 - val_accuracy: 0.7998
# Epoch 51/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4089 - accuracy: 0.8127 - val_loss: 0.4302 - val_accuracy: 0.8038
# Epoch 52/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4091 - accuracy: 0.8125 - val_loss: 0.4308 - val_accuracy: 0.8016
# Epoch 53/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.4084 - accuracy: 0.8146 - val_loss: 0.4307 - val_accuracy: 0.8004
# Epoch 54/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4086 - accuracy: 0.8140 - val_loss: 0.4314 - val_accuracy: 0.8028

# %% [markdown]
# 순환층을 연결하려면 모든 타임스탭의 은닉 상태를 전달해야하므로 마지막 순환층을 제외한 다른 앞에 존재하는 모든 순환층의 옵션으로 return_sequences 매개변수를 True로 설정한다

# %%
model3 = keras.Sequential()
model3.add(keras.layers.Embedding(500,16,input_length=100))
model3.add(keras.layers.LSTM(8,dropout=0.3,return_sequences=True))
model3.add(keras.layers.LSTM(8,dropout=0.3))
model3.add(keras.layers.Dense(1,activation="sigmoid"))
model3.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 100, 16)           8000
#
#  lstm_8 (LSTM)               (None, 100, 8)            800
#
#  lstm_9 (LSTM)               (None, 8)                 544
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 9,353
# Trainable params: 9,353
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GRU셀

# %%
model4 = keras.Sequential()
model4.add(keras.layers.Embedding(500,16,input_length=100))
model4.add(keras.layers.GRU(8))
model4.add(keras.layers.Dense(1,activation="sigmoid"))
model4.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 100, 16)           8000
#
#  gru_2 (GRU)                 (None, 8)                 624
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,633
# Trainable params: 8,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model4.compile(optimizer=rmsprop,loss="binary_crossentropy",metrics=["accuracy"])
checkpoint_cv = keras.callbacks.ModelCheckpoint("./drive/MyDrive/개인 공부/ML_DL/data/best_gru_model.h5")
early_stopping_cb=keras.callbacks.EarlyStopping(patience=3,restore_best_weights=True)
history=model4.fit(train_seq,train_target,epochs=100,batch_size=64,
                   validation_data=(val_seq,val_target),
                   callbacks=[checkpoint_cb,early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 24s 62ms/step - loss: 0.6924 - accuracy: 0.5280 - val_loss: 0.6918 - val_accuracy: 0.5354
# Epoch 2/100
# 313/313 [==============================] - 18s 57ms/step - loss: 0.6902 - accuracy: 0.5688 - val_loss: 0.6891 - val_accuracy: 0.5900
# Epoch 3/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.6863 - accuracy: 0.6080 - val_loss: 0.6849 - val_accuracy: 0.6010
# Epoch 4/100
# 313/313 [==============================] - 22s 70ms/step - loss: 0.6796 - accuracy: 0.6276 - val_loss: 0.6764 - val_accuracy: 0.6206
# Epoch 5/100
# 313/313 [==============================] - 18s 59ms/step - loss: 0.6673 - accuracy: 0.6466 - val_loss: 0.6607 - val_accuracy: 0.6430
# Epoch 6/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.6434 - accuracy: 0.6689 - val_loss: 0.6293 - val_accuracy: 0.6748
# Epoch 7/100
# 313/313 [==============================] - 19s 59ms/step - loss: 0.5873 - accuracy: 0.7046 - val_loss: 0.5510 - val_accuracy: 0.7250
# Epoch 8/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.5208 - accuracy: 0.7473 - val_loss: 0.5151 - val_accuracy: 0.7492
# Epoch 9/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4966 - accuracy: 0.7634 - val_loss: 0.4984 - val_accuracy: 0.7628
# Epoch 10/100
# 313/313 [==============================] - 20s 64ms/step - loss: 0.4801 - accuracy: 0.7764 - val_loss: 0.4822 - val_accuracy: 0.7712
# Epoch 11/100
# 313/313 [==============================] - 19s 59ms/step - loss: 0.4678 - accuracy: 0.7846 - val_loss: 0.4730 - val_accuracy: 0.7794
# Epoch 12/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.4578 - accuracy: 0.7898 - val_loss: 0.4658 - val_accuracy: 0.7864
# Epoch 13/100
# 313/313 [==============================] - 20s 65ms/step - loss: 0.4503 - accuracy: 0.7955 - val_loss: 0.4600 - val_accuracy: 0.7876
# Epoch 14/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.4443 - accuracy: 0.7987 - val_loss: 0.4585 - val_accuracy: 0.7856
# Epoch 15/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.4399 - accuracy: 0.8024 - val_loss: 0.4551 - val_accuracy: 0.7926
# Epoch 16/100
# 313/313 [==============================] - 20s 65ms/step - loss: 0.4361 - accuracy: 0.8048 - val_loss: 0.4515 - val_accuracy: 0.7922
# Epoch 17/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.4320 - accuracy: 0.8068 - val_loss: 0.4496 - val_accuracy: 0.7946
# Epoch 18/100
# 313/313 [==============================] - 19s 61ms/step - loss: 0.4298 - accuracy: 0.8081 - val_loss: 0.4482 - val_accuracy: 0.7946
# Epoch 19/100
# 313/313 [==============================] - 20s 64ms/step - loss: 0.4278 - accuracy: 0.8090 - val_loss: 0.4517 - val_accuracy: 0.7896
# Epoch 20/100
# 313/313 [==============================] - 18s 58ms/step - loss: 0.4263 - accuracy: 0.8087 - val_loss: 0.4459 - val_accuracy: 0.7950
# Epoch 21/100
# 313/313 [==============================] - 19s 59ms/step - loss: 0.4241 - accuracy: 0.8115 - val_loss: 0.4481 - val_accuracy: 0.7944
# Epoch 22/100
# 313/313 [==============================] - 20s 65ms/step - loss: 0.4229 - accuracy: 0.8109 - val_loss: 0.4480 - val_accuracy: 0.7894
# Epoch 23/100
# 313/313 [==============================] - 19s 60ms/step - loss: 0.4217 - accuracy: 0.8134 - val_loss: 0.4470 - val_accuracy: 0.7966

# %%
model4.evaluate(val_seq,val_target)
# Out:
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4459 - accuracy: 0.7950
# [0.4459223747253418, 0.7950000166893005]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
